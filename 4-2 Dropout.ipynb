# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data as mnist_data

# %%
# 载入数据集
mnist = mnist_data.read_data_sets("MNIST_data", one_hot=True)

# 每个批次的大小
batch_size = 100
# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)


# 创建一个简单的神经网络
W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x, W1)+b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000, 2000], stddev=0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop, W2)+b2)
L2_drop = tf.nn.dropout(L2, keep_prob)
W3 = tf.Variable(tf.truncated_normal([2000, 1000], stddev=0.1))
b3 = tf.Variable(tf.zeros([1000])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop, W3)+b3)
L3_drop = tf.nn.dropout(L3, keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000, 10], stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)

prediction = tf.nn.softmax(tf.matmul(L3_drop, W4)+b4)

# 二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))
# 使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个波尔型列表中
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))#argmax返回一维张量中最大的值所在的位置
# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(31):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys, keep_prob:1.0})
            
        test_acc = sess.run(accuracy, feed_dict = {x:mnist.test.images, y:mnist.test.labels, keep_prob:1.0})
        train_acc = sess.run(accuracy, feed_dict = {x:mnist.train.images, y:mnist.train.labels, keep_prob:1.0})
        print("Iter" + str(epoch) + ", Testing Accuracy " + str(test_acc) + ",Training Accuracy " + str(train_acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-4-34b2834d8501>:38: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# Iter0, Testing Accuracy 0.9434,Training Accuracy 0.9525091
# Iter1, Testing Accuracy 0.9541,Training Accuracy 0.97187275
# Iter2, Testing Accuracy 0.9628,Training Accuracy 0.98170906
# Iter3, Testing Accuracy 0.9657,Training Accuracy 0.9858182
# Iter4, Testing Accuracy 0.9678,Training Accuracy 0.98801816
# Iter5, Testing Accuracy 0.9698,Training Accuracy 0.9893818
# Iter6, Testing Accuracy 0.9701,Training Accuracy 0.9902545
# Iter7, Testing Accuracy 0.9702,Training Accuracy 0.99078184
# Iter8, Testing Accuracy 0.9699,Training Accuracy 0.9911818
# Iter9, Testing Accuracy 0.971,Training Accuracy 0.9917455
# Iter10, Testing Accuracy 0.97,Training Accuracy 0.9921273
# Iter11, Testing Accuracy 0.9709,Training Accuracy 0.9925454
# Iter12, Testing Accuracy 0.9709,Training Accuracy 0.9928727
# Iter13, Testing Accuracy 0.9716,Training Accuracy 0.9931818
# Iter14, Testing Accuracy 0.9713,Training Accuracy 0.99341816
# Iter15, Testing Accuracy 0.9717,Training Accuracy 0.9936182
# Iter16, Testing Accuracy 0.9718,Training Accuracy 0.9938727
# Iter17, Testing Accuracy 0.9721,Training Accuracy 0.9941273
# Iter18, Testing Accuracy 0.9716,Training Accuracy 0.99430907
# Iter19, Testing Accuracy 0.9718,Training Accuracy 0.9944909
# Iter20, Testing Accuracy 0.9716,Training Accuracy 0.9946182
# Iter21, Testing Accuracy 0.9727,Training Accuracy 0.9946909
# Iter22, Testing Accuracy 0.9727,Training Accuracy 0.9948182
# Iter23, Testing Accuracy 0.9725,Training Accuracy 0.99485457
# Iter24, Testing Accuracy 0.973,Training Accuracy 0.99494547
# Iter25, Testing Accuracy 0.9729,Training Accuracy 0.99514544
# Iter26, Testing Accuracy 0.9731,Training Accuracy 0.99521816
# Iter27, Testing Accuracy 0.9729,Training Accuracy 0.9952545
# Iter28, Testing Accuracy 0.9728,Training Accuracy 0.9953273
# Iter29, Testing Accuracy 0.9728,Training Accuracy 0.9954364
# Iter30, Testing Accuracy 0.9734,Training Accuracy 0.9954909
